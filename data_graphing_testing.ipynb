# %% [markdown]
# # Veronika Data Analysis

# %%
# %load_ext autoreload
# %autoreload 2

from data_graphing_testing import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
base_path = r'C:\Users\Peter\Downloads\Burn_n=3_renamed.xlsx'
df = pd.read_excel(base_path)
plt.rcParams['ytick.left'] = False

# %%
### palette = {'Control': 'w', '2DG':'w'}
fig_title = 'Comparison of Redox ratio across condtions'
y_axis_label = "Redox Ratio"
boxplot_line_width=2
axis_line_width = 2
swarmplot_size = 10
dotplot_replicate_alpha = 0.4
save_fig = False
save_fig_filename = 'test_export.svg'
x_axis_col_name = 'Group'
y_axis_col_name = 'rr.out'
replicate_id_col_name = 'Repeat'
replicate_list = [1,2,3]
condition_list = ['Tt 24', 'Tt 72', 'Burn 24', 'Burn 72']
replicate_color_list = ['r', 'g', 'b', 'orange', 'purple', 'yellow', '0', '0.4', '0.8', '0.8', '0.4', '0']
assert(len(replicate_color_list) == (len(condition_list)*len(replicate_list)))

# %%
test_dataframe_dict = generate_sub_dataframes(df,
                                              x_axis_col_name,
                                              y_axis_col_name,
                                              replicate_id_col_name,
                                              replicate_list,
                                              replicate_color_list,
                                              condition_list)
generate_figure(test_dataframe_dict,
                condition_list,
                x_axis_col_name,
                y_axis_col_name,
                fig_title,
                y_axis_label,
                swarmplot_size,
                axis_line_width,
                boxplot_line_width,
                dotplot_replicate_alpha,
                save_fig,
                save_fig_filename)
# Out:
# C:\Users\Peter\anaconda3\envs\skala\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Peter\anaconda3\envs\skala\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 32.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Peter\anaconda3\envs\skala\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 13.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Peter\anaconda3\envs\skala\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 22.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
