# %% [markdown]
# # Veronika Data Analysis

# %%
# %load_ext autoreload
# %autoreload 2

from data_graphing_testing import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
base_path = r'C:\Users\Veronika\Desktop\Graphing\Burn_n=3_renamed.xlsx'
df = pd.read_excel(base_path)
plt.rcParams['ytick.left'] = False

# %%
### palette = {'Control': 'w', '2DG':'w'}
fig_title = 'Comparison of Redox ratio across conditions'
figsize = (10,10)
fig_title_size = 25 
fig_title_style = 'normal'
y_axis_label = "Redox Ratio"
y_axis_label_size = 25
y_axis_label_style = 'normal'
x_axis_label = 'test'
x_axis_label_size = 25 
x_axis_label_style = 'normal'
x_axis_data_labels = ['Tt 24h','Burn 24h','Tt 72h','Burn 72h']
x_axis_data_label_size = 25
x_axis_data_label_style= 'normal'
boxplot_line_width=1
axis_line_width = 1
y_axis_tick_thickness = 2
swarmplot_size = 5
dotplot_replicate_alpha = 0.7
boxplot_width = 0.6
save_fig = False
save_fig_filename = 'test_export.svg'
x_axis_col_name = 'Group'
y_axis_col_name = 'rr.out'
replicate_id_col_name = 'Repeat'
replicate_list = [1,2,3]
condition_list = ['Tt 24', 'Burn 24',  'Tt 72','Burn 72']
y_axis_tick_label_size = 25
y_axis_tick_label_style = 'normal'
# Type None for auto scaling
y_axis_ticks = (0,1.2,6)
replicate_color_list = [ '0',
                         '0.6',
                         '0.9',
                         (230/255,111/255,0/255),
                         (255/255,155/255,61/255),
                         (255/255,227/255,201/255),
                         '0',
                         '0.6',
                         '0.9',
                         (230/255,111/255,0/255),
                         (255/255,155/255,61/255),
                         (255/255,227/255,201/255)]
assert(len(x_axis_data_labels) == len(condition_list))
assert(len(replicate_color_list) == (len(condition_list)*len(replicate_list)))
test_dataframe_dict = generate_sub_dataframes(df,
                                              x_axis_col_name,
                                              y_axis_col_name,
                                              replicate_id_col_name,
                                              replicate_list,
                                              replicate_color_list,
                                              condition_list)
generate_figure(test_dataframe_dict,
                condition_list,
                x_axis_col_name,
                y_axis_col_name,
                fig_title,
                figsize,
                fig_title_size, 
                fig_title_style,
                y_axis_label,
                y_axis_label_size,
                y_axis_label_style,
                x_axis_label,
                x_axis_label_size, 
                x_axis_label_style,
                x_axis_data_labels,
                x_axis_data_label_size, 
                x_axis_data_label_style,
                swarmplot_size,
                axis_line_width,
                y_axis_tick_thickness,
                y_axis_tick_label_size, 
                y_axis_tick_label_style, 
                boxplot_line_width,
                boxplot_width,
                dotplot_replicate_alpha,
                save_fig,
                save_fig_filename,
                y_axis_ticks)
# Out:
# C:\Users\Veronika\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
